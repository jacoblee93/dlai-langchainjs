// %% [markdown]
// # Loading and preparing data
//
// The basic flow for RAG is as follows:
//
// 1. Load documents from a source.
// 2. Split the docs into chunks small enough to fit into an LLM's context window and avoid distraction.
// 3. Embed the chunks in a vectorstore to allow for later retrieval based on input queries.
// 4. Retrieval of relevant previously-split chunks.
// 5. Generating a final output with retrieved chunks as context.
//
// ![](./static/images/rag_diagram.png)

// %% [markdown]
// ## Loading
//
// Let's look at an example:

// %%
import "npm:dotenv/config";
// Out:
// [Module: null prototype] { default: {} }

// %%
import { GithubRepoLoader } from "npm:langchain@0.0.178/document_loaders/web/github";
// Peer dependency, used to support .gitignore syntax
import ignore from "npm:ignore";

const loader = new GithubRepoLoader(
  "https://github.com/langchain-ai/langchainjs",
  { recursive: false, ignorePaths: ["*.md", "yarn.lock"] }
);

const docs = await loader.load();
console.log({ docs });
// Out:
// {
//   docs: [
//     Document {
//       pageContent: "# top-most EditorConfig file\n" +
//         "root = true\n" +
//         "\n" +
//         "# Unix-style newlines with a newline ending every file\n" +
//         "[*]"... 17 more characters,
//       metadata: {
//         source: ".editorconfig",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "* text=auto eol=lf",
//       metadata: {
//         source: ".gitattributes",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "node_modules/\n" +
//         "dist/\n" +
//         "dist-cjs/\n" +
//         "lib/\n" +
//         ".turbo\n" +
//         ".eslintcache\n" +
//         ".env\n" +
//         ".env.local\n" +
//         "yarn-error.log\n" +
//         "docs/_dist/\n" +
//         "\n" +
//         "."... 340 more characters,
//       metadata: {
//         source: ".gitignore",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "20\n",
//       metadata: {
//         source: ".nvmrc",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "babel.config.js\njest.config.js\n.eslintrc.js\n",
//       metadata: {
//         source: ".prettierignore",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: '{\n  "endOfLine": "lf"\n}',
//       metadata: {
//         source: ".prettierrc",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "{\n" +
//         '  "ignore_dirs": [\n' +
//         '    "langchain/dist",\n' +
//         '    "langchain/dist-cjs",\n' +
//         '    "docs/build",\n' +
//         '    "node_mod'... 113 more characters,
//       metadata: {
//         source: ".watchmanconfig",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "nodeLinker: node-modules\n" +
//         "\n" +
//         "plugins:\n" +
//         "  - path: .yarn/plugins/@yarnpkg/plugin-typescript.cjs\n" +
//         "    spec: "... 70 more characters,
//       metadata: {
//         source: ".yarnrc.yml",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "The MIT License\n" +
//         "\n" +
//         "Copyright (c) Harrison Chase\n" +
//         "\n" +
//         "Permission is hereby granted, free of charge, to any "... 969 more characters,
//       metadata: {
//         source: "LICENSE",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: 'version: "3"\n' +
//         "services:\n" +
//         "  test-exports-esbuild:\n" +
//         "    image: node:18\n" +
//         "    working_dir: /app\n" +
//         "    volumes:"... 2964 more characters,
//       metadata: {
//         source: "docker-compose.yml",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "{\n" +
//         '  "name": "langchainjs",\n' +
//         '  "version": "0.0.4",\n' +
//         '  "private": true,\n' +
//         '  "engines": {\n' +
//         '    "node": ">=18'... 2352 more characters,
//       metadata: {
//         source: "package.json",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "version: '3.8'\n" +
//         "services:\n" +
//         "  redis:\n" +
//         "    image: redis:6.2-alpine\n" +
//         "    restart: always\n" +
//         "    ports:\n" +
//         "      -"... 647 more characters,
//       metadata: {
//         source: "test-int-deps-docker-compose.yml",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     },
//     Document {
//       pageContent: "{\n" +
//         '  "$schema": "https://turbo.build/schema.json",\n' +
//         '  "globalDependencies": [\n' +
//         '    "**/.env"\n' +
//         "  ],\n" +
//         '  "pi'... 704 more characters,
//       metadata: {
//         source: "turbo.json",
//         repository: "https://github.com/langchain-ai/langchainjs",
//         branch: "main"
//       }
//     }
//   ]
// }

// %% [markdown]
// We can also load from a PDF:

// %%
// Peer dependency
import * as parse from "npm:pdf-parse";
import { PDFLoader } from "npm:langchain@0.0.178/document_loaders/fs/pdf";

// %%
const loader = new PDFLoader("./static/docs/MachineLearning-Lecture01.pdf");

// %%
const rawCS229Docs = await loader.load();

console.log({ docs: rawCS229Docs });
// Out:
// {
//   docs: [
//     Document {
//       pageContent: "MachineLearning-Lecture01  \n" +
//         "Instructor (Andrew Ng):\n" +
//         " Okay. Good morning. Welcome to CS229, the machi"... 3042 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 1 }
//       }
//     },
//     Document {
//       pageContent: "many biologers are there here? Wow, just a \n" +
//         "few, not many. I'm surprised. Anyone from \n" +
//         "statistics? O"... 1024 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 2 }
//       }
//     },
//     Document {
//       pageContent: "So in this class, we've tried to convey to \n" +
//         "you a broad set of principl\n" +
//         "es and tools that will \n" +
//         "be u"... 3209 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3 }
//       }
//     },
//     Document {
//       pageContent: "Similarly, every time you write a check, I ac\n" +
//         "tually don't know the number for this, but a \n" +
//         "signific"... 2946 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 4 }
//       }
//     },
//     Document {
//       pageContent: "of this class will not be very program\n" +
//         "ming intensive, although we will do some \n" +
//         "programming, mostly"... 3025 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 5 }
//       }
//     },
//     Document {
//       pageContent: "So all right, online resources. The class has \n" +
//         "a home page, so it's in on the handouts. I \n" +
//         "won't wri"... 3054 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 6 }
//       }
//     },
//     Document {
//       pageContent: "homework problems with other students, then\n" +
//         " I'll ask you to sort of go home and write \n" +
//         "down your ow"... 2881 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 7 }
//       }
//     },
//     Document {
//       pageContent: "And let's see. Oh, and the goal of the projec\n" +
//         "t should really be for you to do a publishable \n" +
//         "piece "... 2572 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 8 }
//       }
//     },
//     Document {
//       pageContent: "those homeworks will be done in either MATLA\n" +
//         "B or in Octave, which is sort of — I \n" +
//         "know some people "... 2992 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 9 }
//       }
//     },
//     Document {
//       pageContent: "So later this quarter, we'll use the discussion \n" +
//         "sections to talk about things like convex \n" +
//         "optimiza"... 2467 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 10 }
//       }
//     },
//     Document {
//       pageContent: "joys of machine learning firs\n" +
//         "thand and really try to think \n" +
//         "about doing a publishable piece \n" +
//         "of wor"... 3045 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11 }
//       }
//     },
//     Document {
//       pageContent: "So even today, there are some people that \n" +
//         "say, well, computers can't do anything that \n" +
//         "they're not "... 3084 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 12 }
//       }
//     },
//     Document {
//       pageContent: "And this sort of learning pr\n" +
//         "oblem of learning to predict hous\n" +
//         "ing prices is an example of \n" +
//         "what's c"... 3113 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 13 }
//       }
//     },
//     Document {
//       pageContent: "So, for example, what a learning algorithm ma\n" +
//         "y do is maybe come in and decide that a \n" +
//         "straight line"... 3354 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14 }
//       }
//     },
//     Document {
//       pageContent: "algorithm for reading zip codes. When can\n" +
//         " you prove a theorem guaranteeing that a \n" +
//         "learning algorit"... 3153 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 15 }
//       }
//     },
//     Document {
//       pageContent: "classes teach. And this is something I'm rea\n" +
//         "lly convinced is a huge deal, and so by the \n" +
//         "end of thi"... 3205 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 16 }
//       }
//     },
//     Document {
//       pageContent: "I'll just show you one example, and this is a \n" +
//         "rather cool one that two students, Ashutosh \n" +
//         "Saxena a"... 3388 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 17 }
//       }
//     },
//     Document {
//       pageContent: "voices, so slightly different overlapping voice\n" +
//         "s. So Speaker 1's voice may be more loud \n" +
//         "on Microph"... 1765 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 18 }
//       }
//     },
//     Document {
//       pageContent: "Uno, dos, tres, cuatro, cinco, seis, siete, ocho, nueve, diez.  \n" +
//         "Instructor (Andrew Ng): \n" +
//         "And so the"... 1508 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 19 }
//       }
//     },
//     Document {
//       pageContent: "And as an aside, this algorithm I just \n" +
//         "showed you, it seems like it must be a pretty \n" +
//         "complicated a"... 3314 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 20 }
//       }
//     },
//     Document {
//       pageContent: "So the way we teach a helicopter to fly or any \n" +
//         "of these robots is sort of the same thing. \n" +
//         "Every ti"... 2719 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 21 }
//       }
//     },
//     Document {
//       pageContent: "[End of Audio]  \nDuration: 69 minutes \n ",
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 22 }
//       }
//     }
//   ]
// }

// %% [markdown]
// # Splitting
//
// Goal: keep distraction to a minimum while also keeping semantically related idaes together in the same chunk.
//
// // Add example of non-specific splitter
// // Play with sizes, update code inline

// %%
import { RecursiveCharacterTextSplitter } from "npm:langchain@0.0.178/text_splitter";

const splitter = RecursiveCharacterTextSplitter.fromLanguage("js", {
  chunkSize: 64,
  chunkOverlap: 0,
});

const code = `function helloWorld() {
  console.log("Hello, World!");
  console.log("Hello, DLAI!");
  const someVar = 1 + 1;
  }
  // Call the function
  helloWorld();`;
  
await splitter.splitText(code);
// Out:
// [
//   'function helloWorld() {\n  console.log("Hello, World!");',
//   'console.log("Hello, DLAI!");\n  const someVar = 1 + 1;\n  }',
//   "// Call the function\n  helloWorld();"
// ]

// %%
import { CharacterTextSplitter } from "npm:langchain@0.0.178/text_splitter";

const naiveSplitter = new CharacterTextSplitter({
  chunkSize: 10,
  chunkOverlap: 0,
});

const code = `function helloWorld() {
  console.log("Hello, World!");
  }
  // Call the function
  helloWorld();`;
  
await naiveSplitter.splitText(code);
// Out:
// [
//   "function helloWorld() {\n" +
//     '  console.log("Hello, World!");\n' +
//     "  }\n" +
//     "  // Call the function\n" +
//     "  helloWorld();"
// ]

// %%
const splitter = new RecursiveCharacterTextSplitter({
  chunkSize: 512,
  chunkOverlap: 64,
});

// %%
// Peer dependency
import * as parse from "npm:pdf-parse";
import { PDFLoader } from "npm:langchain@0.0.178/document_loaders/fs/pdf";

const loader = new PDFLoader("./static/docs/MachineLearning-Lecture01.pdf");

const rawCS229Docs = await loader.load();

const splitDocs = await splitter.splitDocuments(rawCS229Docs);

console.log({ splitDocs })
// Out:
// {
//   splitDocs: [
//     Document {
//       pageContent: "MachineLearning-Lecture01  \n" +
//         "Instructor (Andrew Ng):\n" +
//         " Okay. Good morning. Welcome to CS229, the machi"... 404 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 1, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "I actually think that machine learning is th\n" +
//         "e most exciting field of all the computer \n" +
//         "sciences. So"... 399 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 1, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "related to the machine learni\n" +
//         "ng and all aspects of machin\n" +
//         "e learning. Paul Baumstarck \n" +
//         "works in mac"... 376 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 1, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "in a row now — works in machine learning a\n" +
//         "nd applies them to a bunch of robots. And \n" +
//         "Daniel Ramage "... 384 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 1, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "in which just the TAs find l\n" +
//         "earning algorithms to problems \n" +
//         "in computer vision and biology and robo"... 380 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 1, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "people from industry coming to Stanford \n" +
//         "interested in applying machine learni\n" +
//         "ng methods to their o"... 377 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 1, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ning. So I think this is a good time to be \n" +
//         "learning this stuff and learning algorithms \n" +
//         "and having "... 405 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 1, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "many biologers are there here? Wow, just a \n" +
//         "few, not many. I'm surprised. Anyone from \n" +
//         "statistics? O"... 407 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 2, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "Chemi.  \n" +
//         "Instructor (Andrew Ng) : \n" +
//         "Chemi. Cool.  \n" +
//         "Student : \n" +
//         "[Inaudible].  \n" +
//         "Instructor (Andrew Ng) :"... 386 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 2, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "Oh, I see, industry. Okay. Cool. Great, great. So as you can \n" +
//         "tell from a cross-section of th\n" +
//         "is cla"... 148 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 2, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "So in this class, we've tried to convey to \n" +
//         "you a broad set of principl\n" +
//         "es and tools that will \n" +
//         "be u"... 387 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "up doing later in your life.  \n" +
//         "So I have more logistics to go over later, \n" +
//         "but let's say a few more "... 391 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "many applications that you can't program by \n" +
//         "hand.  \n" +
//         "For example, if you want to get a computer to \n"... 371 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "longhand. And other things: One thing that my \n" +
//         "students and I do is autonomous flight. It \n" +
//         "turns out"... 388 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "And in fact, handwritten digit \n" +
//         "recognition, this is pretty \n" +
//         "much the only approach that \n" +
//         "works well"... 405 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "what the outcome was. And taking all of \n" +
//         "these medical records, which started to be \n" +
//         "digitized only "... 391 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ecords that hospitals have just been building \n" +
//         "over the last 15, 20 years in an electronic format.  "... 392 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "envelope, and that's done by a learning al\n" +
//         "gorithm. So every time you send US mail, you \n" +
//         "are using a"... 61 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 3, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "Similarly, every time you write a check, I ac\n" +
//         "tually don't know the number for this, but a \n" +
//         "signific"... 395 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 4, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "know at least one phone compan\n" +
//         "y was doing this, and lots of \n" +
//         "companies like eBay as well that do el"... 389 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 4, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: ", these are other examples of learning \n" +
//         "algorithms that have learned what sorts of th\n" +
//         "ings you like "... 370 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 4, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ce for fuel efficiency or something.  \n" +
//         "So, see, most of us use learning algorithms \n" +
//         "half a dozen, a "... 386 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 4, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "works on, yes?  \n" +
//         "So in teaching this class, I sort of have thre\n" +
//         "e goals. One of them is just to I ho"... 365 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 4, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "of this class.  \n" +
//         "And lastly, by the end of this class, I reali\n" +
//         "ze that only a subset of\n" +
//         " you are int"... 387 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 4, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "I'm going to assume that all of you have sort \n" +
//         "of basic knowledge of computer science and kn\n" +
//         "owledge"... 309 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 4, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "of this class will not be very program\n" +
//         "ming intensive, although we will do some \n" +
//         "programming, mostly"... 390 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 5, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "what expectation \n" +
//         "is, what a variance or a random variable is. \n" +
//         "And in case of some of you, it's bee"... 384 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 5, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "linear algebra courses are more than enough. \n" +
//         "So if you've taken courses like Math 51, \n" +
//         "103, Math 11"... 386 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 5, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "But if you don't quite know or if you're not qu\n" +
//         "ite sure, that's fine, too. We'll go over it in \n" +
//         "the"... 374 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 5, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ached SCPD, which televises th\n" +
//         "ese classes, about trying to \n" +
//         "make a small number of Stanford classes"... 398 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 5, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "One of the consequences of this \n" +
//         "is that — let's see — so videos\n" +
//         " or pictures of the students \n" +
//         "in th"... 390 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 5, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "middle of class, but because there won't be \n" +
//         "video you can safely sit there and make faces \n" +
//         "at me, a"... 387 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 5, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "So all right, online resources. The class has \n" +
//         "a home page, so it's in on the handouts. I \n" +
//         "won't wri"... 368 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 6, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "As far as this class, I've also written, a\n" +
//         "nd I guess I've also revised every year a set of \n" +
//         "fairly "... 403 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 6, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "the class to get to\n" +
//         " know each other and \n" +
//         "have whatever discussions you want to ha\n" +
//         "ve amongst yourse"... 376 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 6, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ease use the email address written down here, \n" +
//         "cs229-qa@cs.stanford.edu. This goes to an acc\n" +
//         "ount th"... 390 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 6, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "to, since that will also help us to route \n" +
//         "your question to the appropriate TA or to me\n" +
//         " appropriate"... 387 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 6, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "So start looking around where you'\n" +
//         "re sitting now or at the \n" +
//         "end of class today, mingle a \n" +
//         "little bi"... 397 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 6, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ss are reasonably difficult.\n" +
//         " People that have \n" +
//         "taken the class before may tell you they were \n" +
//         "very "... 384 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 6, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "homework problems with other students, then\n" +
//         " I'll ask you to sort of go home and write \n" +
//         "down your ow"... 403 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 7, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "people, okay? And obviously, \n" +
//         "showing your solutions to othe\n" +
//         "rs or copying other solutions\n" +
//         " directly"... 378 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 7, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "rations of this class and previous solutions \n" +
//         "that people that have taken this class \n" +
//         "in previous ye"... 384 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 7, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "solutions, and hopefully there'll be zero honor code\n" +
//         " violations this year. I'd love for that \n" +
//         "to ha"... 393 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 7, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "y is about the class \n" +
//         "project. So part of the goal of this cla\n" +
//         "ss is to leave you well eq\n" +
//         "uipped to "... 385 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 7, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "machine learning. So to those of you that \n" +
//         "are either already doing research or to those \n" +
//         "of you who"... 389 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 7, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "em to work using a learning algorithm.  \n" +
//         "To those of you that are not currently doing re\n" +
//         "search, one"... 244 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 7, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "And let's see. Oh, and the goal of the projec\n" +
//         "t should really be for you to do a publishable \n" +
//         "piece "... 392 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 8, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "plied learning \n" +
//         "algorithms to control a snake robot. Ther\n" +
//         "e was a few projects \n" +
//         "on improving learnin"... 403 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 8, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "learning algorithms; one on musical instrume\n" +
//         "nt detection; anot\n" +
//         "her on irony sequence \n" +
//         "alignment; an"... 398 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 8, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "person's face physically attractive. There's a \n" +
//         "learning algorithm on op\n" +
//         "tical illusions, and \n" +
//         "so on"... 391 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 8, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "Instructor (Andrew Ng): \n" +
//         "Right. So projects can be done in\n" +
//         " groups of up to three people. \n" +
//         "So as par"... 390 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 8, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "with us.  \n" +
//         "Okay. So one more organizational ques\n" +
//         "tion. I'm curious, how many of you know \n" +
//         "MATLAB? Wo"... 315 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 8, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "those homeworks will be done in either MATLA\n" +
//         "B or in Octave, which is sort of — I \n" +
//         "know some people "... 385 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 9, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "plot data. And it's sort of an extremely easy to\n" +
//         " learn tool to use for implementing a lot of \n" +
//         "learn"... 366 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 9, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "MATLAB, but it's free, and for the purposes of\n" +
//         " this class, it will work for just about \n" +
//         "everything."... 403 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 9, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: 'into his office and he said, "Oh, professo\n' +
//         "r, professor, thank you so much for your \n" +
//         "machine learnin"... 391 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 9, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "logistic regression? Was it \n" +
//         "the PCA? Was it the data ne\n" +
//         "tworks? What was it that you \n" +
//         "learned that "... 368 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 9, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ing is the discussion s\n" +
//         "ections. So discussion \n" +
//         "sections will be taught by the TAs, and atte\n" +
//         "ndance "... 402 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 9, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "go over those in the discussion sections as a \n" +
//         "refresher for those of you that want one.  \n" +
//         "Later in "... 281 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 9, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "So later this quarter, we'll use the discussion \n" +
//         "sections to talk about things like convex \n" +
//         "optimiza"... 382 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 10, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ogistics. Before we move on \n" +
//         "to start talking a bit about \n" +
//         "machine learning, let me check what quest"... 382 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 10, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "somewhat painful for you to translate into R \n" +
//         "yourself. So for your other assignments, if \n" +
//         "you wanna"... 398 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 10, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "groups of three, or you're welcome to do it by yo\n" +
//         "urself or in groups of two. Grading is the \n" +
//         "same r"... 409 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 10, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "your project. So all \n" +
//         "the homeworks can be \n" +
//         "done in MATLAB or Octave, and let's see. A\n" +
//         "nd I guess th"... 405 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 10, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "Instructor (Andrew Ng) : \n" +
//         "Of the project?  \n" +
//         "Student : \n" +
//         "Yeah.  \n" +
//         "Instructor (Andrew Ng) : \n" +
//         "Yeah, let m"... 235 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 10, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "joys of machine learning firs\n" +
//         "thand and really try to think \n" +
//         "about doing a publishable piece \n" +
//         "of wor"... 370 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "at will sometimes try to prove — develop the \n" +
//         "theory of machine learning further or try to\n" +
//         " prove th"... 369 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "uld you lower the big sc\n" +
//         "reen? Cool. This is \n" +
//         "amazing customer service. Thank you. I see. Okay, cool"... 383 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "and they said 4,000-to-1 something or othe\n" +
//         "r brightness ratio. I don't know. Someone was \n" +
//         "very excit"... 391 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "So what is machine learning? Way back in\n" +
//         " about 1959, Arthur Samuel defined machine \n" +
//         "learning inform"... 391 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "against itself.  \n" +
//         "And so because a computer can play thousands\n" +
//         " of games against itself relatively q"... 371 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: 'win," or, "Gee, if I get my pieces into a \n' +
//         "certain position, then I'm especially li\n" +
//         "kely to win rath"... 405 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "learned to play checkers much better \n" +
//         "than Arthur Samuel\n" +
//         " himself could.",
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 11, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "So even today, there are some people that \n" +
//         "say, well, computers can't do anything that \n" +
//         "they're not "... 377 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 12, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "they were not programmed explicitly to do.  \n" +
//         "Here's a more recent, a more modern, more \n" +
//         "formal defin"... 372 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 12, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "only is it a definition, it even rhymes.  \n" +
//         "So, for example, in the case of checkers, th\n" +
//         "e experience"... 390 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 12, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "eckers program has learned to play checkers, \n" +
//         "okay?  \n" +
//         "So as an overview of what we're going to do in"... 398 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 12, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "me last week to use in the \n" +
//         "example later. But suppose that \n" +
//         "you go to collect statistics about how "... 406 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 12, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "sted for different amounts of money.  \n" +
//         "Now, let's say that I'm trying to sell a hous\n" +
//         "e in the same a"... 393 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 12, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "and maybe put a straight\n" +
//         " line to it. And then \n" +
//         "if this is my house, you may then look at th\n" +
//         "e strai"... 398 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 12, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "And this sort of learning pr\n" +
//         "oblem of learning to predict hous\n" +
//         "ing prices is an example of \n" +
//         "what's c"... 397 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 13, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "we're supervising the algorithm or, in other \n" +
//         "words, we're giving the algorithm the, quote,\n" +
//         " right a"... 393 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 13, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "you're trying to predict is a \n" +
//         "continuous value and price.  \n" +
//         "There's another class of supervised lea"... 367 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 13, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "people have played with. Let's say you collect\n" +
//         " a data set on breast cancer tumors, and you \n" +
//         "want to"... 401 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 13, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "going to look at the size of the tumor and depe\n" +
//         "nding on the size of the tumor, we'll try to \n" +
//         "figure"... 400 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 13, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "is a discreet value. It\n" +
//         "'s either zero or 1.  \n" +
//         "And in fact, more generally, there will be \n" +
//         "many lear"... 409 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 13, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "data set look much cleaner than it really \n" +
//         "is in reality for illustration, okay?  \n" +
//         "For example, mayb"... 395 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 13, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "So, for example, what a learning algorithm ma\n" +
//         "y do is maybe come in and decide that a \n" +
//         "straight line"... 382 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "And so it turns out that one of the issues we'\n" +
//         "ll talk about later in this class is in this \n" +
//         "specifi"... 396 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "ample, you also use properties \n" +
//         "of the tumors, like clump thic\n" +
//         "kness, uniformity of cell size, \n" +
//         "unif"... 409 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "dimensional space? Our plots here are two-dime\n" +
//         "nsional space. I can't plot you an infinite \n" +
//         "dimensio"... 383 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "And that will actually be one of the most fa\n" +
//         "scinating things we talk about when we go \n" +
//         "deeply into "... 371 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "support vector machines, okay?  \n" +
//         "So let's see. So that was supervised learning. \n" +
//         "The second of the f"... 380 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "wonder in his eyes, and he'll tell you about how in his \n" +
//         "mathematical work, he feels like he's disc\n"... 402 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "I'm gonna talk about \n" +
//         "learning theory to try to convey to y\n" +
//         "ou an understanding of how and why learn"... 272 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 14, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "algorithm for reading zip codes. When can\n" +
//         " you prove a theorem guaranteeing that a \n" +
//         "learning algorit"... 397 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 15, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "training data do you need? So how many exampl\n" +
//         "es of houses do I need in order for your \n" +
//         "learning alg"... 390 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 15, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "Okay?  \n" +
//         "So I think learning algorithms \n" +
//         "are a very powerful tool that\n" +
//         " as I walk around sort of \n" +
//         "ind"... 373 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 15, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "is imagine you were going to a carpentry school instead of \n" +
//         "a machine learning class, right? If you "... 378 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 15, lines: [Object] }
//       }
//     },
//     Document {
//       pageContent: "possibly. And it's actually a littl\n" +
//         "e bit like that in machine \n" +
//         "learning, too. One thing that's \n" +
//         "sad"... 407 more characters,
//       metadata: {
//         source: "./static/docs/MachineLearning-Lecture01.pdf",
//         pdf: {
//           version: "1.10.100",
//           info: [Object],
//           metadata: [Metadata],
//           totalPages: 22
//         },
//         loc: { pageNumber: 15, lines: [Object] }
//       }
//     },
//     ... 43 more items
//   ]
// }
